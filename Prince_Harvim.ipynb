# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Prince Harvim
# ### Data Science

# %% [markdown]
# ### I am interested in data science because I like application of mathematics and statistics and I want to use these tools to solve problems for humanity.

# %% [markdown]
# ### My code plots the graph of y = x^2

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,5,100);
# the function to be ploted is y = x^2 
y = x**2;

# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r')

# show the plot
plt.show()

# %%
 - One
 - two
 - three
 - four

# %% [markdown]
# | --- | --- | --- |
# | Age | Gender | Income |
# | --- | --- | --- |
# | 36 | Male | $15000 |
